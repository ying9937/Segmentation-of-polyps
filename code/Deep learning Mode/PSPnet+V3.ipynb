# %%
import numpy as np
from tensorflow.keras.models import save_model, load_model, Model
from tensorflow.keras.layers import Input, Dropout, BatchNormalization, LeakyReLU, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Conv2DTranspose
import h5py 
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import segmentation_models as sm
import tensorflow.keras
# from tensorflow import keras
# from tensorflow.keras.layers import Input
# Out:
# Segmentation Models: using `keras` framework.

# %%
# 读取训练集
fh5 = h5py.File(r'E:\wujieyu\img train PolypGen+CVC\img Highlights processing FMM\imgandmasks_Highlights_processing_percentile=99.5.h5','r')
#fh5 = h5py.File(r'D:\PolypGen+CVCtrain_imgandmasks.h5','r')
img_png_x = fh5['img']
img_png_x = np.array(img_png_x)
#img_gray_c = fh5['img_gray']
#img_gray_c = np.array(img_gray_c)
mask_x = fh5['masks']
mask_x = np.array(mask_x)

# %%
img_png_x.shape
# Out:
# (2987, 288, 384, 3)

# %%
mask_x.shape
# Out:
# (2987, 288, 384)

# %%
img_png_x.max()
# Out:
# 1.0

# %%
mask_x.max()
# Out:
# 1.0

# %%
mask_x  = mask_x .reshape(len(mask_x),288, 384, 1)
mask_x .shape
# Out:
# (2987, 288, 384, 1)

# %%
# mask_x = mask_x/255

# %%
mask_x.max()
# Out:
# 1.0

# %%
# 划分训练集与验证集
# 划分训练集与验证集
# 划分训练集与验证集
# T_img_png_x
# T_mask_x
# V_img
# V_mask

# %%
# -----------------------------------------------------------------
# 从txt文件读取并恢复为NumPy数组
# -----------------------------------------------------------------
# 读取训练集
Train = np.loadtxt('D:\edge\Train.txt', dtype=int)
# 读取验证集
Val = np.loadtxt('D:\edge\Val.txt', dtype=int)

# %%
Train.shape
# Out:
# (2390,)

# %%
Val.shape
# Out:
# (597,)

# %%
# -----------------------------------------------------------------
# 按索引划分图像数据
# -----------------------------------------------------------------
# 划分训练集（T_img_png_x）和验证集（V_img）
T_img = img_png_x[Train]
V_img = img_png_x[Val]

T_mask = mask_x[Train]
V_mask = mask_x[Val]

# %%
print(  T_img.shape,
        V_img.shape,
        T_mask.shape,
        V_mask.shape)
# Out:
# (2390, 288, 384, 3) (597, 288, 384, 3) (2390, 288, 384, 1) (597, 288, 384, 1)

# %%
# 查看训练集集
a = 10
plt.figure()
plt.subplot(121),plt.imshow(T_img[a,:,:,0])
plt.axis('off')
plt.subplot(122),plt.imshow(T_mask[a],'gray')
plt.axis('off')
# Out:
# (-0.5, 383.5, 287.5, -0.5)

# %%
# 查看验证集
a = 10
plt.figure()
plt.subplot(121),plt.imshow(V_img[a,:,:,0])
plt.axis('off')
plt.subplot(122),plt.imshow(V_mask[a],'gray')
plt.axis('off')
# Out:
# (-0.5, 383.5, 287.5, -0.5)

# %%
BACKBONE = 'inceptionv3'##骨架

# %%
model = sm.PSPNet(BACKBONE, input_shape=(288, 384, 3), classes=1, activation="sigmoid")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 288, 384, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 144, 192, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 144, 192, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 144, 192, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 144, 192, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 144, 192, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 144, 192, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 144, 192, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 144, 192, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 144, 192, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 72, 96, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 72, 96, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 72, 96, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 72, 96, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 72, 96, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 72, 96, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 72, 96, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 36, 48, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 36, 48, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 36, 48, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 36, 48, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 36, 48, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 36, 48, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 36, 48, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 36, 48, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 36, 48, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 36, 48, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 36, 48, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 36, 48, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 36, 48, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 36, 48, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 36, 48, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 36, 48, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 36, 48, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 36, 48, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 36, 48, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 36, 48, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 36, 48, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 36, 48, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 36, 48, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 36, 48, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 36, 48, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 36, 48, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 36, 48, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 36, 48, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 36, 48, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 36, 48, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 36, 48, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 36, 48, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 36, 48, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 36, 48, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 36, 48, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 36, 48, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 36, 48, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 36, 48, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 36, 48, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 36, 48, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 36, 48, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 36, 48, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 36, 48, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 36, 48, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 36, 48, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 36, 48, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 36, 48, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 36, 48, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 36, 48, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 36, 48, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 36, 48, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 36, 48, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 36, 48, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 36, 48, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 36, 48, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 36, 48, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 36, 48, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 36, 48, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 36, 48, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 36, 48, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 36, 48, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 36, 48, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 36, 48, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  psp_level1_pooling (AveragePoo  (None, 1, 1, 288)   0           ['mixed2[0][0]']
#  ling2D)
#
#  psp_level2_pooling (AveragePoo  (None, 2, 2, 288)   0           ['mixed2[0][0]']
#  ling2D)
#
#  psp_level3_pooling (AveragePoo  (None, 3, 3, 288)   0           ['mixed2[0][0]']
#  ling2D)
#
#  psp_level6_pooling (AveragePoo  (None, 6, 6, 288)   0           ['mixed2[0][0]']
#  ling2D)
#
#  psp_level1_conv (Conv2D)       (None, 1, 1, 512)    147456      ['psp_level1_pooling[0][0]']
#
#  psp_level2_conv (Conv2D)       (None, 2, 2, 512)    147456      ['psp_level2_pooling[0][0]']
#
#  psp_level3_conv (Conv2D)       (None, 3, 3, 512)    147456      ['psp_level3_pooling[0][0]']
#
#  psp_level6_conv (Conv2D)       (None, 6, 6, 512)    147456      ['psp_level6_pooling[0][0]']
#
#  psp_level1_bn (BatchNormalizat  (None, 1, 1, 512)   2048        ['psp_level1_conv[0][0]']
#  ion)
#
#  psp_level2_bn (BatchNormalizat  (None, 2, 2, 512)   2048        ['psp_level2_conv[0][0]']
#  ion)
#
#  psp_level3_bn (BatchNormalizat  (None, 3, 3, 512)   2048        ['psp_level3_conv[0][0]']
#  ion)
#
#  psp_level6_bn (BatchNormalizat  (None, 6, 6, 512)   2048        ['psp_level6_conv[0][0]']
#  ion)
#
#  psp_level1_relu (Activation)   (None, 1, 1, 512)    0           ['psp_level1_bn[0][0]']
#
#  psp_level2_relu (Activation)   (None, 2, 2, 512)    0           ['psp_level2_bn[0][0]']
#
#  psp_level3_relu (Activation)   (None, 3, 3, 512)    0           ['psp_level3_bn[0][0]']
#
#  psp_level6_relu (Activation)   (None, 6, 6, 512)    0           ['psp_level6_bn[0][0]']
#
#  psp_level1_upsampling (UpSampl  (None, 36, 48, 512)  0          ['psp_level1_relu[0][0]']
#  ing2D)
#
#  psp_level2_upsampling (UpSampl  (None, 36, 48, 512)  0          ['psp_level2_relu[0][0]']
#  ing2D)
#
#  psp_level3_upsampling (UpSampl  (None, 36, 48, 512)  0          ['psp_level3_relu[0][0]']
#  ing2D)
#
#  psp_level6_upsampling (UpSampl  (None, 36, 48, 512)  0          ['psp_level6_relu[0][0]']
#  ing2D)
#
#  psp_concat (Concatenate)       (None, 36, 48, 2336  0           ['mixed2[0][0]',
#                                 )                                 'psp_level1_upsampling[0][0]',
#                                                                   'psp_level2_upsampling[0][0]',
#                                                                   'psp_level3_upsampling[0][0]',
#                                                                   'psp_level6_upsampling[0][0]']
#
#  aggregation_conv (Conv2D)      (None, 36, 48, 512)  1196032     ['psp_concat[0][0]']
#
#  aggregation_bn (BatchNormaliza  (None, 36, 48, 512)  2048       ['aggregation_conv[0][0]']
#  tion)
#
#  aggregation_relu (Activation)  (None, 36, 48, 512)  0           ['aggregation_bn[0][0]']
#
#  final_conv (Conv2D)            (None, 36, 48, 1)    4609        ['aggregation_relu[0][0]']
#
#  final_upsampling (UpSampling2D  (None, 288, 384, 1)  0          ['final_conv[0][0]']
#  )
#
#  sigmoid (Activation)           (None, 288, 384, 1)  0           ['final_upsampling[0][0]']
#
# ==================================================================================================
# Total params: 2,793,761
# Trainable params: 2,784,929
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
model.compile(
    'Adam',
    loss=sm.losses.bce_jaccard_loss,
    metrics=[sm.metrics.iou_score],
)

# %%
import keras
callbacks_list = [
    keras.callbacks.ReduceLROnPlateau(  monitor='val_iou_score',  # 监控指标（默认：val_loss）
                                        factor=0.5,               # 学习率衰减系数（新学习率 = 旧学习率 * factor）
                                        patience=20,              # 等待 epoch 数无改善后触发
                                        mode='max'              # 监控指标方向：'auto'/'min'/'max'（自动检测最大/最小化）
                                        # min_delta=0.0001,         # 视为“改善”的最小变化阈值
                                        # cooldown=0,               # 触发后暂停监控的 epoch 数（防止频繁调整）
                                        # min_lr=0                  # 学习率下限（避免过小导致训练停滞）
                                     ),

    
    keras.callbacks.ModelCheckpoint(filepath=r'E:\wujieyu\IoU best\PSPnet+V3\FMM+percentile=99.5-1\img_FMM+percentile=99.5_bestweigh_epoch_{epoch:03d}_val_iou_{val_iou_score:.4f}.h5', 
                                    # 保存路径（支持 epoch 变量，如 model_{epoch:02d}.h5）
                                    monitor='val_iou_score',
                                    save_best_only=True,           # 只保留最优模型
                                    save_weights_only=True,       # 若为 True 只保存权重，否则保存完整模型
                                    mode='max'                   # 监控指标方向（与 ReduceLROnPlateau 相同）
                                   )   ##保存最佳模型
                                      
    #keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=0, mode='auto', 
                                  #baseline=None, restore_best_weights=False)
    ]

# %%
# 模型训练
model.fit(
       x=T_img,
       y=T_mask,
       # validation_split=0.2,  # 验证集
       batch_size=8,
       epochs=300,
       validation_data=(V_img, V_mask),
       callbacks = callbacks_list
)
# Out:
# Epoch 1/300
# 299/299 [==============================] - 19s 45ms/step - loss: 0.8080 - iou_score: 0.4182 - val_loss: 0.8972 - val_iou_score: 0.4383 - lr: 0.0010
# Epoch 2/300
# 299/299 [==============================] - 12s 39ms/step - loss: 0.5991 - iou_score: 0.5631 - val_loss: 0.8568 - val_iou_score: 0.4350 - lr: 0.0010
# Epoch 3/300
# 299/299 [==============================] - 12s 40ms/step - loss: 0
300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0397 - iou_score: 0.9687 - val_loss: 0.4527 - val_iou_score: 0.7690 - lr: 5.0000e-04
# Epoch 81/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0395 - iou_score: 0.9689 - val_loss: 0.4717 - val_iou_score: 0.7642 - lr: 5.0000e-04
# Epoch 82/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0388 - iou_score: 0.9694 - val_loss: 0.4885 - val_iou_score: 0.7624 - lr: 5.0000e-04
# Epoch 83/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0387 - iou_score: 0.9694 - val_loss: 0.4508 - val_iou_score: 0.7702 - lr: 5.0000e-04
# Epoch 84/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0379 - iou_score: 0.9701 - val_loss: 0.4729 - val_iou_score: 0.7609 - lr: 5.0000e-04
# Epoch 85/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0385 - iou_score: 0.9696 - val_loss: 0.4933 - val_iou_score: 0.7579 - lr: 5.0000e-04
# Epoch 86/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0367 - iou_score: 0.9711 - val_loss: 0.4713 - val_iou_score: 0.7703 - lr: 5.0000e-04
# Epoch 87/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0361 - iou_score: 0.9714 - val_loss: 0.5126 - val_iou_score: 0.7597 - lr: 5.0000e-04
# Epoch 88/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0338 - iou_score: 0.9732 - val_loss: 0.4889 - val_iou_score: 0.7656 - lr: 2.5000e-04
# Epoch 89/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0309 - iou_score: 0.9754 - val_loss: 0.4920 - val_iou_score: 0.7692 - lr: 2.5000e-04
# Epoch 90/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0302 - iou_score: 0.9759 - val_loss: 0.4988 - val_iou_score: 0.7668 - lr: 2.5000e-04
# Epoch 91/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0303 - iou_score: 0.9757 - val_loss: 0.4908 - val_iou_score: 0.7701 - lr: 2.5000e-04
# Epoch 92/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0295 - iou_score: 0.9765 - val_loss: 0.5131 - val_iou_score: 0.7649 - lr: 2.5000e-04
# Epoch 93/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0296 - iou_score: 0.9763 - val_loss: 0.5073 - val_iou_score: 0.7690 - lr: 2.5000e-04
# Epoch 94/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0295 - iou_score: 0.9765 - val_loss: 0.5157 - val_iou_score: 0.7645 - lr: 2.5000e-04
# Epoch 95/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0292 - iou_score: 0.9767 - val_loss: 0.5081 - val_iou_score: 0.7685 - lr: 2.5000e-04
# Epoch 96/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0296 - iou_score: 0.9764 - val_loss: 0.5308 - val_iou_score: 0.7651 - lr: 2.5000e-04
# Epoch 97/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0284 - iou_score: 0.9774 - val_loss: 0.5150 - val_iou_score: 0.7686 - lr: 2.5000e-04
# Epoch 98/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0285 - iou_score: 0.9773 - val_loss: 0.5054 - val_iou_score: 0.7677 - lr: 2.5000e-04
# Epoch 99/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0281 - iou_score: 0.9777 - val_loss: 0.5432 - val_iou_score: 0.7629 - lr: 2.5000e-04
# Epoch 100/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0279 - iou_score: 0.9778 - val_loss: 0.5294 - val_iou_score: 0.7652 - lr: 2.5000e-04
# Epoch 101/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0280 - iou_score: 0.9777 - val_loss: 0.5510 - val_iou_score: 0.7646 - lr: 2.5000e-04
# Epoch 102/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0275 - iou_score: 0.9781 - val_loss: 0.5089 - val_iou_score: 0.7670 - lr: 2.5000e-04
# Epoch 103/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0274 - iou_score: 0.9783 - val_loss: 0.5648 - val_iou_score: 0.7623 - lr: 2.5000e-04
# Epoch 104/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0277 - iou_score: 0.9780 - val_loss: 0.5792 - val_iou_score: 0.7602 - lr: 2.5000e-04
# Epoch 105/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0274 - iou_score: 0.9782 - val_loss: 0.5461 - val_iou_score: 0.7632 - lr: 2.5000e-04
# Epoch 106/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0269 - iou_score: 0.9786 - val_loss: 0.5602 - val_iou_score: 0.7635 - lr: 2.5000e-04
# Epoch 107/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0269 - iou_score: 0.9786 - val_loss: 0.5345 - val_iou_score: 0.7666 - lr: 2.5000e-04
# Epoch 108/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0257 - iou_score: 0.9796 - val_loss: 0.5487 - val_iou_score: 0.7661 - lr: 1.2500e-04
# Epoch 109/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0246 - iou_score: 0.9804 - val_loss: 0.5448 - val_iou_score: 0.7655 - lr: 1.2500e-04
# Epoch 110/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0244 - iou_score: 0.9805 - val_loss: 0.5598 - val_iou_score: 0.7651 - lr: 1.2500e-04
# Epoch 111/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0245 - iou_score: 0.9803 - val_loss: 0.5679 - val_iou_score: 0.7635 - lr: 1.2500e-04
# Epoch 112/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0243 - iou_score: 0.9806 - val_loss: 0.5800 - val_iou_score: 0.7613 - lr: 1.2500e-04
# Epoch 113/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0240 - iou_score: 0.9809 - val_loss: 0.5636 - val_iou_score: 0.7633 - lr: 1.2500e-04
# Epoch 114/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0243 - iou_score: 0.9805 - val_loss: 0.5665 - val_iou_score: 0.7642 - lr: 1.2500e-04
# Epoch 115/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0238 - iou_score: 0.9810 - val_loss: 0.5810 - val_iou_score: 0.7621 - lr: 1.2500e-04
# Epoch 116/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0240 - iou_score: 0.9809 - val_loss: 0.5721 - val_iou_score: 0.7652 - lr: 1.2500e-04
# Epoch 117/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0235 - iou_score: 0.9813 - val_loss: 0.5762 - val_iou_score: 0.7623 - lr: 1.2500e-04
# Epoch 118/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0236 - iou_score: 0.9812 - val_loss: 0.5791 - val_iou_score: 0.7620 - lr: 1.2500e-04
# Epoch 119/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0232 - iou_score: 0.9815 - val_loss: 0.5880 - val_iou_score: 0.7619 - lr: 1.2500e-04
# Epoch 120/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0233 - iou_score: 0.9815 - val_loss: 0.5784 - val_iou_score: 0.7635 - lr: 1.2500e-04
# Epoch 121/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0231 - iou_score: 0.9816 - val_loss: 0.5727 - val_iou_score: 0.7647 - lr: 1.2500e-04
# Epoch 122/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0231 - iou_score: 0.9816 - val_loss: 0.5757 - val_iou_score: 0.7643 - lr: 1.2500e-04
# Epoch 123/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0229 - iou_score: 0.9818 - val_loss: 0.5818 - val_iou_score: 0.7626 - lr: 1.2500e-04
# Epoch 124/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0229 - iou_score: 0.9818 - val_loss: 0.5751 - val_iou_score: 0.7640 - lr: 1.2500e-04
# Epoch 125/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0230 - iou_score: 0.9817 - val_loss: 0.5943 - val_iou_score: 0.7626 - lr: 1.2500e-04
# Epoch 126/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0226 - iou_score: 0.9820 - val_loss: 0.5835 - val_iou_score: 0.7642 - lr: 1.2500e-04
# Epoch 127/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0228 - iou_score: 0.9819 - val_loss: 0.5873 - val_iou_score: 0.7652 - lr: 1.2500e-04
# Epoch 128/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0221 - iou_score: 0.9825 - val_loss: 0.5950 - val_iou_score: 0.7636 - lr: 6.2500e-05
# Epoch 129/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0220 - iou_score: 0.9825 - val_loss: 0.5841 - val_iou_score: 0.7640 - lr: 6.2500e-05
# Epoch 130/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.
300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0194 - iou_score: 0.9845 - val_loss: 0.6432 - val_iou_score: 0.7597 - lr: 4.8828e-07
# Epoch 280/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0192 - iou_score: 0.9848 - val_loss: 0.6435 - val_iou_score: 0.7599 - lr: 4.8828e-07
# Epoch 281/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0194 - iou_score: 0.9845 - val_loss: 0.6424 - val_iou_score: 0.7598 - lr: 4.8828e-07
# Epoch 282/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0193 - iou_score: 0.9846 - val_loss: 0.6417 - val_iou_score: 0.7601 - lr: 4.8828e-07
# Epoch 283/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0195 - iou_score: 0.9845 - val_loss: 0.6448 - val_iou_score: 0.7597 - lr: 4.8828e-07
# Epoch 284/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0198 - iou_score: 0.9842 - val_loss: 0.6441 - val_iou_score: 0.7599 - lr: 4.8828e-07
# Epoch 285/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0193 - iou_score: 0.9846 - val_loss: 0.6431 - val_iou_score: 0.7598 - lr: 4.8828e-07
# Epoch 286/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0193 - iou_score: 0.9846 - val_loss: 0.6425 - val_iou_score: 0.7598 - lr: 4.8828e-07
# Epoch 287/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0195 - iou_score: 0.9845 - val_loss: 0.6412 - val_iou_score: 0.7600 - lr: 4.8828e-07
# Epoch 288/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0196 - iou_score: 0.9844 - val_loss: 0.6420 - val_iou_score: 0.7599 - lr: 2.4414e-07
# Epoch 289/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0192 - iou_score: 0.9847 - val_loss: 0.6441 - val_iou_score: 0.7598 - lr: 2.4414e-07
# Epoch 290/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0191 - iou_score: 0.9848 - val_loss: 0.6441 - val_iou_score: 0.7599 - lr: 2.4414e-07
# Epoch 291/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0194 - iou_score: 0.9846 - val_loss: 0.6448 - val_iou_score: 0.7597 - lr: 2.4414e-07
# Epoch 292/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0194 - iou_score: 0.9846 - val_loss: 0.6439 - val_iou_score: 0.7599 - lr: 2.4414e-07
# Epoch 293/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0192 - iou_score: 0.9847 - val_loss: 0.6449 - val_iou_score: 0.7598 - lr: 2.4414e-07
# Epoch 294/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0196 - iou_score: 0.9843 - val_loss: 0.6427 - val_iou_score: 0.7600 - lr: 2.4414e-07
# Epoch 295/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0194 - iou_score: 0.9846 - val_loss: 0.6406 - val_iou_score: 0.7600 - lr: 2.4414e-07
# Epoch 296/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0193 - iou_score: 0.9847 - val_loss: 0.6451 - val_iou_score: 0.7598 - lr: 2.4414e-07
# Epoch 297/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0193 - iou_score: 0.9846 - val_loss: 0.6429 - val_iou_score: 0.7598 - lr: 2.4414e-07
# Epoch 298/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0197 - iou_score: 0.9843 - val_loss: 0.6427 - val_iou_score: 0.7600 - lr: 2.4414e-07
# Epoch 299/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0197 - iou_score: 0.9842 - val_loss: 0.6410 - val_iou_score: 0.7600 - lr: 2.4414e-07
# Epoch 300/300
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0195 - iou_score: 0.9845 - val_loss: 0.6432 - val_iou_score: 0.7599 - lr: 2.4414e-07

# %%
model.save_weights(r'E:\wujieyu\IoU best\PSPnet+V3\FMM+percentile=99.5-1\300img_FMM+percentile=99.5_weigh.h5')
# #路径文件名

# %%
# 读取测试集
fh5 = h5py.File(r'E:\wujieyu\img test\TestDataset\CVC-ColonDB\images\test_CVC-ColonDB_imgandmasks.h5','r')
#fh5 = h5py.File(r'D:\PolypGen+CVCtrain_imgandmasks.h5','r')
img_png_c = fh5['img']
img_png_c = np.array(img_png_c)
mask_c = fh5['masks']
mask_c = np.array(mask_c)

# %%
img_png_c.max()
# Out:
# 1.0

# %%
mask_c = mask_c/255

# %%
mask_c[1].max()
# Out:
# 1.0

# %%
# 读取测试集
fh5 = h5py.File(r'E:\wujieyu\img test\TestDataset\CVC-ColonDB\img Highlights processing FMM\test_CVC-ColonDB_imgandmasks_Highlights_percentile=99.5.h5','r')
#fh5 = h5py.File(r'D:\PolypGen+CVCtrain_imgandmasks.h5','r')
img_png_c1 = fh5['img']
img_png_c1 = np.array(img_png_c1)
mask_c1 = fh5['masks']
mask_c1 = np.array(mask_c1)

# %%
img_png_c1.max()
# Out:
# 1.0

# %%
mask_c1[1].max()
# Out:
# 1.0

# %%
a = 10
plt.figure()
plt.subplot(121),plt.imshow(img_png_c[a])
plt.axis('off')
plt.subplot(122),plt.imshow(mask_c[a],'gray')
plt.axis('off')
# Out:
# (-0.5, 383.5, 287.5, -0.5)

# %%
a = 10
plt.figure()
plt.subplot(121),plt.imshow(img_png_c1[a])
plt.axis('off')
plt.subplot(122),plt.imshow(mask_c1[a],'gray')
plt.axis('off')
# Out:
# (-0.5, 383.5, 287.5, -0.5)

# %%
import tensorflow as tf

def bce_jaccard_loss(y_true, y_pred, smooth=1e-7, alpha=0.5):
    """
    参数说明：
    - y_true: 真实标签 (shape=[batch, H, W, 1])
    - y_pred: 模型预测值 (shape=[batch, H, W, 1])
    - smooth: 防止除零的小常数
    - alpha: 平衡 BCE 和 Jaccard 的权重（默认 0.5）
    """
    # 计算二元交叉熵
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    
    # 计算 Jaccard Loss (IoU Loss)  
    y_true_f = tf.keras.backend.flatten(y_true)   # 展平为向量 [batch*H*W]
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    jaccard_loss = 1 - jaccard  # 将 IoU 转换为 Loss
    
    # 加权组合
    return alpha * bce + (1 - alpha) * jaccard_loss

# %%
def dice_score(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    denominator = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    return (2.0 * intersection + smooth) / (denominator + smooth)

# %%
# def iou_score(y_true, y_pred, smooth=1e-7):
#     y_true_f = tf.keras.backend.flatten(y_true)
#     y_pred_f = tf.keras.backend.flatten(y_pred)
#     intersection = tf.reduce_sum(y_true_f * y_pred_f)
#     union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
#     return (intersection + smooth) / (union + smooth)

# %%
model.compile(
    optimizer='Adam',
    loss=bce_jaccard_loss,  # 可替换为 iou_loss 或 bce_jaccard_loss
    metrics=[
        dice_score, 
        sm.metrics.iou_score
        # tf.keras.metrics.BinaryAccuracy()  # 可选：添加准确率指标
    ]
)

# %%
# # 加载模型
model.load_weights(r'E:\wujieyu\IoU best\PSPnet+V3\img\img_bestweigh_epoch_085_val_iou_0.7800.h5', by_name=True)

# %%
# 评估模型（返回 loss + metrics）
results = model.evaluate(img_png_c, mask_c, verbose=0)

# %%
# 打印所有指标名称和值
print("\n=== 测试结果 ===")
print(f"Loss: {results[0]:.4f}")
print(f"dice_score: {results[1]:.4f}")
print(f"iou_score: {results[2]:.4f}")
# Out:
# === 测试结果 ===
# Loss: 0.4400
# dice_score: 0.7268
# iou_score: 0.6074

# %%
# # 加载模型
model.load_weights(r'E:\wujieyu\IoU best\PSPnet+V3\FMM+percentile=99.5\img_FMM+percentile=99.5_bestweigh_epoch_067_val_iou_0.7743.h5', by_name=True)

# %%
# 新方法评估模型（返回 loss + metrics）
results1 = model.evaluate(img_png_c1, mask_c1, verbose=0)

# %%
# 打印所有指标名称和值
print("\n=== 测试结果 ===")
print(f"Loss: {results1[0]:.4f}")
print(f"dice_score: {results1[1]:.4f}")
print(f"iou_score: {results1[2]:.4f}")
# Out:
# === 测试结果 ===
# Loss: 0.4308
# dice_score: 0.7323
# iou_score: 0.6194

# %%
# # 加载模型
model.load_weights(r'E:\wujieyu\IoU best\PSPnet+V3\img\img_bestweigh_epoch_085_val_iou_0.7800.h5', by_name=True)

# %%
#测试mask
imgp = model.predict(img_png_c, verbose=1)
# Out:
# 12/12 [==============================] - 4s 75ms/step

# %%
# # 加载模型
model.load_weights(r'E:\wujieyu\IoU best\PSPnet+V3\FMM+percentile=99.5\img_FMM+percentile=99.5_bestweigh_epoch_067_val_iou_0.7743.h5', by_name=True)

# %%
#测试mask
imgp1 = model.predict(img_png_c1, verbose=1)
# Out:
# 12/12 [==============================] - 0s 30ms/step

# %%
a, b, c = 8, 117, 311

# 设置更大的画布和紧凑布局
plt.figure(figsize=(24, 6))  # 宽度增加，高度适当调整
plt.subplots_adjust(wspace=0.02, 
                    left=0.01, 
                    right=0.99, 
                    top=0.5, 
                    bottom=0.05)  # 调整左右边距和子图间距

# 第1组子图
plt.subplot(1,12,1)
plt.imshow(img_png_c[a])
plt.axis('off')
plt.subplot(1,12,2)
plt.imshow(mask_c[a], 'gray')
plt.axis('off')
plt.subplot(1,12,3)
plt.imshow(imgp[a].reshape(288, 384), cmap='gray')
plt.axis('off')
plt.subplot(1,12,4)
plt.imshow(imgp1[a].reshape(288, 384), cmap='gray')
plt.axis('off')
# 第2组子图
plt.subplot(1,12,5)
plt.imshow(img_png_c[b])
plt.axis('off')
plt.subplot(1,12,6)
plt.imshow(mask_c[b], 'gray')
plt.axis('off')
plt.subplot(1,12,7)
plt.imshow(imgp[b].reshape(288, 384), cmap='gray')
plt.axis('off')
plt.subplot(1,12,8)
plt.imshow(imgp1[b].reshape(288, 384), cmap='gray')
plt.axis('off')
# 第3组子图
plt.subplot(1,12,9)
plt.imshow(img_png_c[c])
plt.axis('off')
plt.subplot(1,12,10)
plt.imshow(mask_c[c], 'gray')
plt.axis('off')
plt.subplot(1,12,11)
plt.imshow(imgp[c].reshape(288, 384), cmap='gray')
plt.axis('off')
plt.subplot(1,12,12)
plt.imshow(imgp1[c].reshape(288, 384), cmap='gray')
plt.axis('off')

plt.show()

# %%
a = 340
# 创建紧凑画布
fig = plt.figure(figsize=(6, 3))

# 使用GridSpec控制微小边距
gs = fig.add_gridspec(2, 1, 
                     hspace=0.02,  # 行间距
                     left=0.01,    # 左边距
                     right=0.99,   # 右边距
                     top=0.99,     # 上边距
                     bottom=0.01)  # 下边距

# 添加图像子图
ax1 = fig.add_subplot(gs[0])
ax1.imshow(imgp[a].reshape(288, 384), 'gray')
ax1.axis('off')
ax1.margins(0.01)  # 图像周围微小边距

ax2 = fig.add_subplot(gs[1])
ax2.imshow(imgp1[a].reshape(288, 384), 'gray')
ax2.axis('off')
ax2.margins(0.01)  # 图像周围微小边距

# 显示紧凑布局
plt.show()
